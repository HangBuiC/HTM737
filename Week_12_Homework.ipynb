# %% [markdown]
# <a href="https://colab.research.google.com/github/HangBuiC/HTM737/blob/main/Week_12_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Key Takeaway:
#
# 1. Before coding, always make sure to check the tools that we may use in scikit library.
# 2. Build the model: 3 lines (import -> define -> fit the model).
# 3. Then we test the model to see how accuracy it is. (check the Accuracy and AUC). Remind: AUC from 0.5 - 1 is considered high.

# %%
import pandas as pd
X_train = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/X_train_clean.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/X_test_clean.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/y_train.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/y_test.csv')

y_train = y_train.values.ravel()

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 86.8%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.00      0.00      0.00       817
#
#     accuracy                           0.87      6195
#    macro avg       0.43      0.50      0.46      6195
# weighted avg       0.75      0.87      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5375    3]
#  [ 817    0]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.724

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#Support Vector Machine

from sklearn.svm import SVC

model = SVC(probability=True)

model.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 86.8%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.00      0.00      0.00       817
#
#     accuracy                           0.87      6195
#    macro avg       0.43      0.50      0.46      6195
# weighted avg       0.75      0.87      0.81      6195
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5378    0]
#  [ 817    0]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.477

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)

# %%
#Random Forest

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 82.6%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      5378
#            1       0.25      0.16      0.19       817
#
#     accuracy                           0.83      6195
#    macro avg       0.56      0.54      0.55      6195
# weighted avg       0.80      0.83      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[4991  387]
#  [ 688  129]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.648

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)

# %%
#Neural Network

from sklearn.neural_network import MLPClassifier

model = MLPClassifier()

model.fit(X_train, y_train)
# Out:
# MLPClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 86.6%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.21      0.01      0.01       817
#
#     accuracy                           0.87      6195
#    macro avg       0.54      0.50      0.47      6195
# weighted avg       0.78      0.87      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5359   19]
#  [ 812    5]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.716

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)
