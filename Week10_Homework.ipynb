# %% [markdown]
# <a href="https://colab.research.google.com/github/HangBuiC/HTM737/blob/main/Week10_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#My Key takeaway:
#Always check the content inside the file to see: Whether the key value is written the same in everyfile, whether there is any duplicated column)
#We can use Python to export csv file.
#E.g: 'df_master.to_csv('hvbp.csv', index=False)'
#Then check folders on the left side

# %%
import pandas as pd

# %%
df_clinical_care = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/hvbp_clinical_care_11_07_2017.csv')
df_clinical_care.head()
# Out:
#    Provider Number                     Hospital Name  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10005     MARSHALL MEDICAL CENTER SOUTH
# 2            10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3            10007          MIZELL MEMORIAL HOSPITAL
# 4            10011                 ST VINCENT'S EAST
#
#                       Address        City State  ZIP Code County Name  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     Houston
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957    Marshall
# 2          205 MARENGO STREET    FLORENCE    AL     35631  Lauderdale
# 3               702 N MAIN ST         OPP    AL     36467   Covington
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235   Jefferson
#
#    MORT-30-AMI Achievement Threshold  MORT-30-AMI Benchmark  \
# 0                           0.850916               0.873053
# 1                           0.850916               0.873053
# 2                           0.850916               0.873053
# 3                           0.850916               0.873053
# 4                           0.850916               0.873053
#
#   MORT-30-AMI Baseline Rate  ... MORT-30-HF Achievement Points  \
# 0                  0.850186  ...                   1 out of 10
# 1                  0.836946  ...                   0 out of 10
# 2                  0.818278  ...                   0 out of 10
# 3                  0.843930  ...                   0 out of 10
# 4                  0.834080  ...                   0 out of 10
#
#   MORT-30-HF Improvement Points MORT-30-HF Measure Score  \
# 0                    0 out of 9              1 out of 10
# 1                    0 out of 9              0 out of 10
# 2                    0 out of 9              0 out of 10
# 3                    0 out of 9              0 out of 10
# 4                    0 out of 9              0 out of 10
#
#   MORT-30-PN Achievement Threshold  MORT-30-PN Benchmark  \
# 0                          0.88286                0.9079
# 1                          0.88286                0.9079
# 2                          0.88286                0.9079
# 3                          0.88286                0.9079
# 4                          0.88286                0.9079
#
#    MORT-30-PN Baseline Rate MORT-30-PN Performance Rate  \
# 0                  0.877181                    0.893777
# 1                  0.858520                    0.851953
# 2                  0.848835                    0.872522
# 3                  0.836245                    0.849107
# 4                  0.823954                    0.883768
#
#   MORT-30-PN Achievement Points MORT-30-PN Improvement Points  \
# 0                   4 out of 10                    5 out of 9
# 1                   0 out of 10                    0 out of 9
# 2                   0 out of 10                    4 out of 9
# 3                   0 out of 10                    1 out of 9
# 4                   1 out of 10                    7 out of 9
#
#   MORT-30-PN Measure Score
# 0              5 out of 10
# 1              0 out of 10
# 2              4 out of 10
# 3              1 out of 10
# 4              7 out of 10
#
# [5 rows x 28 columns]

# %%
df_efficiency = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/hvbp_efficiency_11_07_2017.csv')
df_efficiency.head()
# Out:
#    Provider_Number                        Hospital_Name  \
# 0           110215            PIEDMONT FAYETTE HOSPITAL
# 1           230236                METRO HEALTH HOSPITAL
# 2           520019        MINISTRY SAINT MARYS HOSPITAL
# 3           340141  NEW HANOVER REGIONAL MEDICAL CENTER
# 4           200020                        YORK HOSPITAL
#
#                         Address          City State  ZIP_Code  County_Name  \
# 0          1255 HIGHWAY 54 WEST  FAYETTEVILLE    GA     30214      Fayette
# 1  5900 BYRON CENTER AVENUE, SW       WYOMING    MI     49519         Kent
# 2           2251 NORTH SHORE DR   RHINELANDER    WI     54501       Oneida
# 3       2131 S 17TH ST BOX 9000    WILMINGTON    NC     28402  New Hanover
# 4             15 HOSPITAL DRIVE          YORK    ME      3909         York
#
#    MSPB-1 Achievement Threshold  MSPB-1 Benchmark MSPB-1 Baseline Rate  \
# 0                      0.985777          0.832678             0.950527
# 1                      0.985777          0.832678             0.921788
# 2                      0.985777          0.832678             0.843599
# 3                      0.985777          0.832678             0.966919
# 4                      0.985777          0.832678             0.966664
#
#    MSPB-1 Performance Rate MSPB-1 Achievement Points  \
# 0                 0.962057               2 out of 10
# 1                 0.939953               3 out of 10
# 2                 0.832790               9 out of 10
# 3                 0.967548               2 out of 10
# 4                 0.970079               1 out of 10
#
#   MSPB-1 Improvement Points MSPB-1 Measure Score
# 0                0 out of 9          2 out of 10
# 1                0 out of 9          3 out of 10
# 2                9 out of 9          9 out of 10
# 3                0 out of 9          2 out of 10
# 4                0 out of 9          1 out of 10

# %%
df_hcahps = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/hvbp_hcahps_11_07_2017.csv')
df_hcahps.head()
# Out:
#    Provider Number                                     Hospital Name  \
# 0           240040  UNIVERSITY MEDICAL CENTER-MESABI/ MESABA CLINICS
# 1           450055                  ROLLING PLAINS MEMORIAL HOSPITAL
# 2            50367                           NORTHBAY MEDICAL CENTER
# 3           360096                      EAST LIVERPOOL CITY HOSPITAL
# 4           230130                      BEAUMONT HOSPITAL, ROYAL OAK
#
#                     Address            City State  ZIP Code  County Name  \
# 0          750 EAST 34TH ST         HIBBING    MN     55746  Saint Louis
# 1             200 E ARIZONA      SWEETWATER    TX     79556        Nolan
# 2  1200 B  GALE WILSON BLVD       FAIRFIELD    CA     94533       Solano
# 3       425 WEST 5TH STREET  EAST LIVERPOOL    OH     43920   Columbiana
# 4   3601 W THIRTEEN MILE RD       ROYAL OAK    MI     48073      Oakland
#
#    Communication with Nurses Floor  \
# 0                            55.27
# 1                            55.27
# 2                            55.27
# 3                            55.27
# 4                            55.27
#
#    Communication with Nurses Achievement Threshold  \
# 0                                            78.52
# 1                                            78.52
# 2                                            78.52
# 3                                            78.52
# 4                                            78.52
#
#    Communication with Nurses Benchmark  ... Overall Rating of Hospital Floor  \
# 0                                86.68  ...                            37.67
# 1                                86.68  ...                            37.67
# 2                                86.68  ...                            37.67
# 3                                86.68  ...                            37.67
# 4                                86.68  ...                            37.67
#
#    Overall Rating of Hospital Achievement Threshold  \
# 0                                             70.23
# 1                                             70.23
# 2                                             70.23
# 3                                             70.23
# 4                                             70.23
#
#   Overall Rating of Hospital Benchmark  \
# 0                                84.58
# 1                                84.58
# 2                                84.58
# 3                                84.58
# 4                                84.58
#
#   Overall Rating of Hospital Baseline Rate  \
# 0                                    69.20
# 1                                    73.47
# 2                                    69.92
# 3                                    60.70
# 4                                    72.39
#
#   Overall Rating of Hospital Performance Rate  \
# 0                                       72.81
# 1                                       79.06
# 2                                       71.60
# 3                                       70.32
# 4                                       73.51
#
#    Overall Rating of Hospital Achievement Points  \
# 0                                    2 out of 10
# 1                                    6 out of 10
# 2                                    1 out of 10
# 3                                    1 out of 10
# 4                                    3 out of 10
#
#    Overall Rating of Hospital Improvement Points  \
# 0                                     2 out of 9
# 1                                     5 out of 9
# 2                                     1 out of 9
# 3                                     4 out of 9
# 4                                     0 out of 9
#
#    Overall Rating of Hospital Dimension Score HCAHPS Base Score  \
# 0                                 2 out of 10                29
# 1                                 6 out of 10                49
# 2                                 1 out of 10                10
# 3                                 4 out of 10                29
# 4                                 3 out of 10                 7
#
#    HCAHPS Consistency Score
# 0                        19
# 1                        20
# 2                        13
# 3                        16
# 4                        14
#
# [5 rows x 73 columns]

# %%
df_safety = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/hvbp_safety_11_07_2017.csv')
df_safety.head()
# Out:
#    Provider Number                     Hospital Name  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10005     MARSHALL MEDICAL CENTER SOUTH
# 2            10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3            10007          MIZELL MEMORIAL HOSPITAL
# 4            10011                 ST VINCENT'S EAST
#
#                       Address        City State  ZIP Code County Name  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     Houston
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957    Marshall
# 2          205 MARENGO STREET    FLORENCE    AL     35631  Lauderdale
# 3               702 N MAIN ST         OPP    AL     36467   Covington
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235   Jefferson
#
#    PSI-90 Achievement Threshold  PSI-90 Benchmark PSI-90 Baseline Rate  ...  \
# 0                      0.964542          0.709498             1.009846  ...
# 1                      0.964542          0.709498             0.798330  ...
# 2                      0.964542          0.709498             1.253606  ...
# 3                      0.964542          0.709498             1.101822  ...
# 4                      0.964542          0.709498             0.864237  ...
#
#   HAI-6 Achievement Points HAI-6 Improvement Points HAI-6 Measure Score  \
# 0              6 out of 10               7 out of 9         7 out of 10
# 1              9 out of 10               8 out of 9         9 out of 10
# 2              5 out of 10               3 out of 9         5 out of 10
# 3            Not Available            Not Available       Not Available
# 4              3 out of 10               3 out of 9         3 out of 10
#
#   PC-01 Achievement Threshold  PC-01 Benchmark  PC-01 Baseline Rate  \
# 0                    0.020408              0.0             0.000000
# 1                    0.020408              0.0             0.295858
# 2                    0.020408              0.0             0.027027
# 3                    0.020408              0.0        Not Available
# 4                    0.020408              0.0             0.058824
#
#   PC-01 Performance Rate PC-01 Achievement Points PC-01 Improvement Points  \
# 0               0.000000             10 out of 10               0 out of 9
# 1               0.021739              0 out of 10               9 out of 9
# 2               0.000000             10 out of 10               9 out of 9
# 3          Not Available            Not Available            Not Available
# 4               0.000000             10 out of 10               9 out of 9
#
#   PC-01 Measure Score
# 0        10 out of 10
# 1         9 out of 10
# 2        10 out of 10
# 3       Not Available
# 4        10 out of 10
#
# [5 rows x 64 columns]

# %%
df_tps = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/hvbp_tps_11_07_2017.csv')
df_tps.head()
# Out:
#    Provider Number                     Hospital Name  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10005     MARSHALL MEDICAL CENTER SOUTH
# 2            10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3            10007          MIZELL MEMORIAL HOSPITAL
# 4            10011                 ST VINCENT'S EAST
#
#                       Address        City State  Zip Code County Name  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     Houston
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957    Marshall
# 2          205 MARENGO STREET    FLORENCE    AL     35631  Lauderdale
# 3               702 N MAIN ST         OPP    AL     36467   Covington
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235   Jefferson
#
#   Unweighted Normalized Clinical Care Domain Score  \
# 0                                  43.333333333333
# 1                                  16.666666666667
# 2                                  26.666666666667
# 3                                  26.666666666667
# 4                                  46.666666666667
#
#   Weighted Normalized Clinical Care Domain Score  \
# 0                                10.833333333333
# 1                                 4.166666666667
# 2                                 6.666666666667
# 3                                 8.888888888889
# 4                                11.666666666667
#
#   Unweighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                    26.000000000000
# 1                                    36.000000000000
# 2                                    17.000000000000
# 3                                    56.000000000000
# 4                                    25.000000000000
#
#   Weighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                     6.500000000000
# 1                                     9.000000000000
# 2                                     4.250000000000
# 3                                    18.666666666667
# 4                                     6.250000000000
#
#   Unweighted Normalized Safety Domain Score Weighted Safety Domain Score  \
# 0                           72.857142857143              18.214285714286
# 1                           81.428571428571              20.357142857143
# 2                           47.142857142857              11.785714285714
# 3                             Not Available                Not Available
# 4                           42.857142857143              10.714285714286
#
#   Unweighted Normalized Efficiency and Cost Reduction Domain Score  \
# 0                                     0.000000000000
# 1                                     0.000000000000
# 2                                     0.000000000000
# 3                                     0.000000000000
# 4                                     0.000000000000
#
#   Weighted Efficiency and Cost Reduction Domain Score Total Performance Score
# 0                                     0.000000000000          35.547619047619
# 1                                     0.000000000000          33.523809523810
# 2                                     0.000000000000          22.702380952381
# 3                                     0.000000000000          27.555555555556
# 4                                     0.000000000000          28.630952380952

# %%
pathname = 'https://raw.githubusercontent.com/osoliman/Chapter6_HTM737/refs/heads/main/'
files_of_interest = [
    'hvbp_tps_11_07_2017.csv',
    'hvbp_clinical_care_11_07_2017.csv',
    'hvbp_safety_11_07_2017.csv',
    'hvbp_efficiency_11_07_2017.csv',
    'hvbp_hcahps_11_07_2017.csv'
]

dfs = {
    foi: pd.read_csv(pathname + foi, header=0) for foi in files_of_interest #Header=0 means taking the 1st row. (remind: in python we start from 0)
}

# %%
type(dfs)
# Out:
# dict

# %%
dfs.items() #check the item in the dictionary
# Out:
# dict_items([('hvbp_tps_11_07_2017.csv',       Provider Number                                      Hospital Name  \
# 0               10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1               10005                      MARSHALL MEDICAL CENTER SOUTH
# 2               10006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3               10007                           MIZELL MEMORIAL HOSPITAL
# 4               10011                                  ST VINCENT'S EAST
# ...               ...                                                ...
# 2803           670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 2804           670098                           RESOLUTE HEALTH HOSPITAL
# 2805           670103                              MEDICAL CITY ALLIANCE
# 2806           670106                            PEARLAND MEDICAL CENTER
# 2807           670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                          Address           City State  Zip Code County Name  \
# 0         1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301     Houston
# 1     2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957    Marshall
# 2             205 MARENGO STREET       FLORENCE    AL     35631  Lauderdale
# 3                  702 N MAIN ST            OPP    AL     36467   Covington
# 4     50 MEDICAL PARK EAST DRIVE     BIRMINGHAM    AL     35235   Jefferson
# ...                          ...            ...   ...       ...         ...
# 2803          200 BLOSSOM STREET        WEBSTER    TX     77598      Harris
# 2804         555 CREEKSIDE XING,  NEW BRAUNFELS    TX     78130       Comal
# 2805  3101 NORTH TARRANT PARKWAY     FORT WORTH    TX     76177     Tarrant
# 2806  11100 SHADOW CREEK PARKWAY       PEARLAND    TX     77584    Brazoria
# 2807            810 W HIGHWAY 71   MARBLE FALLS    TX     78654      Burnet
#
#      Unweighted Normalized Clinical Care Domain Score  \
# 0                                     43.333333333333
# 1                                     16.666666666667
# 2                                     26.666666666667
# 3                                     26.666666666667
# 4                                     46.666666666667
# ...                                               ...
# 2803                                  60.000000000000
# 2804                                  20.000000000000
# 2805                                    Not Available
# 2806                                    Not Available
# 2807                                    Not Available
#
#      Weighted Normalized Clinical Care Domain Score  \
# 0                                   10.833333333333
# 1                                    4.166666666667
# 2                                    6.666666666667
# 3                                    8.888888888889
# 4                                   11.666666666667
# ...                                             ...
# 2803                                15.000000000000
# 2804                                 5.000000000000
# 2805                                  Not Available
# 2806                                  Not Available
# 2807                                  Not Available
#
#      Unweighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                       26.000000000000
# 1                                       36.000000000000
# 2                                       17.000000000000
# 3                                       56.000000000000
# 4                                       25.000000000000
# ...                                                 ...
# 2803                                    20.000000000000
# 2804                                    49.000000000000
# 2805                                    55.000000000000
# 2806                                    47.000000000000
# 2807                                    70.000000000000
#
#      Weighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                        6.500000000000
# 1                                        9.000000000000
# 2                                        4.250000000000
# 3                                       18.666666666667
# 4                                        6.250000000000
# ...                                                 ...
# 2803                                     5.000000000000
# 2804                                    12.250000000000
# 2805                                    18.333333333333
# 2806                                    15.666666666667
# 2807                                    23.333333333333
#
#      Unweighted Normalized Safety Domain Score Weighted Safety Domain Score  \
# 0                              72.857142857143              18.214285714286
# 1                              81.428571428571              20.357142857143
# 2                              47.142857142857              11.785714285714
# 3                                Not Available                Not Available
# 4                              42.857142857143              10.714285714286
# ...                                        ...                          ...
# 2803                           80.000000000000              20.000000000000
# 2804                           86.666666666667              21.666666666667
# 2805                           66.666666666667              22.222222222222
# 2806                           33.333333333333              11.111111111111
# 2807                           76.666666666667              25.555555555556
#
#      Unweighted Normalized Efficiency and Cost Reduction Domain Score  \
# 0                                        0.000000000000
# 1                                        0.000000000000
# 2                                        0.000000000000
# 3                                        0.000000000000
# 4                                        0.000000000000
# ...                                                 ...
# 2803                                     0.000000000000
# 2804                                     0.000000000000
# 2805                                     0.000000000000
# 2806                                     0.000000000000
# 2807                                     0.000000000000
#
#      Weighted Efficiency and Cost Reduction Domain Score  \
# 0                                        0.000000000000
# 1                                        0.000000000000
# 2                                        0.000000000000
# 3                                        0.000000000000
# 4                                        0.000000000000
# ...                                                 ...
# 2803                                     0.000000000000
# 2804                                     0.000000000000
# 2805                                     0.000000000000
# 2806                                     0.000000000000
# 2807                                     0.000000000000
#
#      Total Performance Score
# 0            35.547619047619
# 1            33.523809523810
# 2            22.702380952381
# 3            27.555555555556
# 4            28.630952380952
# ...                      ...
# 2803         40.000000000000
# 2804         38.916666666667
# 2805         40.555555555556
# 2806         26.777777777778
# 2807         48.888888888889
#
# [2808 rows x 16 columns]), ('hvbp_clinical_care_11_07_2017.csv',       Provider Number                                      Hospital Name  \
# 0               10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1               10005                      MARSHALL MEDICAL CENTER SOUTH
# 2               10006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3               10007                           MIZELL MEMORIAL HOSPITAL
# 4               10011                                  ST VINCENT'S EAST
# ...               ...                                                ...
# 2803           670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 2804           670098                           RESOLUTE HEALTH HOSPITAL
# 2805           670103                              MEDICAL CITY ALLIANCE
# 2806           670106                            PEARLAND MEDICAL CENTER
# 2807           670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                          Address           City State  ZIP Code County Name  \
# 0         1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301     Houston
# 1     2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957    Marshall
# 2             205 MARENGO STREET       FLORENCE    AL     35631  Lauderdale
# 3                  702 N MAIN ST            OPP    AL     36467   Covington
# 4     50 MEDICAL PARK EAST DRIVE     BIRMINGHAM    AL     35235   Jefferson
# ...                          ...            ...   ...       ...         ...
# 2803          200 BLOSSOM STREET        WEBSTER    TX     77598      Harris
# 2804         555 CREEKSIDE XING,  NEW BRAUNFELS    TX     78130       Comal
# 2805  3101 NORTH TARRANT PARKWAY     FORT WORTH    TX     76177     Tarrant
# 2806  11100 SHADOW CREEK PARKWAY       PEARLAND    TX     77584    Brazoria
# 2807            810 W HIGHWAY 71   MARBLE FALLS    TX     78654      Burnet
#
#       MORT-30-AMI Achievement Threshold  MORT-30-AMI Benchmark  \
# 0                              0.850916               0.873053
# 1                              0.850916               0.873053
# 2                              0.850916               0.873053
# 3                              0.850916               0.873053
# 4                              0.850916               0.873053
# ...                                 ...                    ...
# 2803                           0.850916               0.873053
# 2804                           0.850916               0.873053
# 2805                           0.850916               0.873053
# 2806                           0.850916               0.873053
# 2807                           0.850916               0.873053
#
#      MORT-30-AMI Baseline Rate  ... MORT-30-HF Achievement Points  \
# 0                     0.850186  ...                   1 out of 10
# 1                     0.836946  ...                   0 out of 10
# 2                     0.818278  ...                   0 out of 10
# 3                     0.843930  ...                   0 out of 10
# 4                     0.834080  ...                   0 out of 10
# ...                        ...  ...                           ...
# 2803             Not Available  ...                   2 out of 10
# 2804             Not Available  ...                   1 out of 10
# 2805             Not Available  ...                 Not Available
# 2806             Not Available  ...                 Not Available
# 2807             Not Available  ...                 Not Available
#
#      MORT-30-HF Improvement Points MORT-30-HF Measure Score  \
# 0                       0 out of 9              1 out of 10
# 1                       0 out of 9              0 out of 10
# 2                       0 out of 9              0 out of 10
# 3                       0 out of 9              0 out of 10
# 4                       0 out of 9              0 out of 10
# ...                            ...                      ...
# 2803                 Not Available              2 out of 10
# 2804                 Not Available              1 out of 10
# 2805                 Not Available            Not Available
# 2806                 Not Available            Not Available
# 2807                 Not Available            Not Available
#
#      MORT-30-PN Achievement Threshold  MORT-30-PN Benchmark  \
# 0                             0.88286                0.9079
# 1                             0.88286                0.9079
# 2                             0.88286                0.9079
# 3                             0.88286                0.9079
# 4                             0.88286                0.9079
# ...                               ...                   ...
# 2803                          0.88286                0.9079
# 2804                          0.88286                0.9079
# 2805                          0.88286                0.9079
# 2806                          0.88286                0.9079
# 2807                          0.88286                0.9079
#
#       MORT-30-PN Baseline Rate MORT-30-PN Performance Rate  \
# 0                     0.877181                    0.893777
# 1                     0.858520                    0.851953
# 2                     0.848835                    0.872522
# 3                     0.836245                    0.849107
# 4                     0.823954                    0.883768
# ...                        ...                         ...
# 2803             Not Available                    0.898293
# 2804             Not Available                    0.890056
# 2805             Not Available                    0.894962
# 2806             Not Available                    0.895677
# 2807             Not Available                    0.896352
#
#      MORT-30-PN Achievement Points MORT-30-PN Improvement Points  \
# 0                      4 out of 10                    5 out of 9
# 1                      0 out of 10                    0 out of 9
# 2                      0 out of 10                    4 out of 9
# 3                      0 out of 10                    1 out of 9
# 4                      1 out of 10                    7 out of 9
# ...                            ...                           ...
# 2803                   6 out of 10                 Not Available
# 2804                   3 out of 10                 Not Available
# 2805                 Not Available                 Not Available
# 2806                 Not Available                 Not Available
# 2807                   5 out of 10                 Not Available
#
#      MORT-30-PN Measure Score
# 0                 5 out of 10
# 1                 0 out of 10
# 2                 4 out of 10
# 3                 1 out of 10
# 4                 7 out of 10
# ...                       ...
# 2803              6 out of 10
# 2804              3 out of 10
# 2805            Not Available
# 2806            Not Available
# 2807              5 out of 10
#
# [2808 rows x 28 columns]), ('hvbp_safety_11_07_2017.csv',       Provider Number                                      Hospital Name  \
# 0               10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1               10005                      MARSHALL MEDICAL CENTER SOUTH
# 2               10006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3               10007                           MIZELL MEMORIAL HOSPITAL
# 4               10011                                  ST VINCENT'S EAST
# ...               ...                                                ...
# 2803           670096              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 2804           670098                           RESOLUTE HEALTH HOSPITAL
# 2805           670103                              MEDICAL CITY ALLIANCE
# 2806           670106                            PEARLAND MEDICAL CENTER
# 2807           670108  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                          Address           City State  ZIP Code County Name  \
# 0         1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301     Houston
# 1     2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957    Marshall
# 2             205 MARENGO STREET       FLORENCE    AL     35631  Lauderdale
# 3                  702 N MAIN ST            OPP    AL     36467   Covington
# 4     50 MEDICAL PARK EAST DRIVE     BIRMINGHAM    AL     35235   Jefferson
# ...                          ...            ...   ...       ...         ...
# 2803          200 BLOSSOM STREET        WEBSTER    TX     77598      Harris
# 2804         555 CREEKSIDE XING,  NEW BRAUNFELS    TX     78130       Comal
# 2805  3101 NORTH TARRANT PARKWAY     FORT WORTH    TX     76177     Tarrant
# 2806  11100 SHADOW CREEK PARKWAY       PEARLAND    TX     77584    Brazoria
# 2807            810 W HIGHWAY 71   MARBLE FALLS    TX     78654      Burnet
#
#       PSI-90 Achievement Threshold  PSI-90 Benchmark PSI-90 Baseline Rate  \
# 0                         0.964542          0.709498             1.009846
# 1                         0.964542          0.709498             0.798330
# 2                         0.964542          0.709498             1.253606
# 3                         0.964542          0.709498             1.101822
# 4                         0.964542          0.709498             0.864237
# ...                            ...               ...                  ...
# 2803                      0.964542          0.709498        Not Available
# 2804                      0.964542          0.709498        Not Available
# 2805                      0.964542          0.709498        Not Available
# 2806                      0.964542          0.709498        Not Available
# 2807                      0.964542          0.709498        Not Available
#
#       ... HAI-6 Achievement Points HAI-6 Improvement Points  \
# 0     ...              6 out of 10               7 out of 9
# 1     ...              9 out of 10               8 out of 9
# 2     ...              5 out of 10               3 out of 9
# 3     ...            Not Available            Not Available
# 4     ...              3 out of 10               3 out of 9
# ...   ...                      ...                      ...
# 2803  ...              0 out of 10            Not Available
# 2804  ...              2 out of 10               1 out of 9
# 2805  ...              0 out of 10            Not Available
# 2806  ...              0 out of 10            Not Available
# 2807  ...              3 out of 10            Not Available
#
#      HAI-6 Measure Score PC-01 Achievement Threshold  PC-01 Benchmark  \
# 0            7 out of 10                    0.020408              0.0
# 1            9 out of 10                    0.020408              0.0
# 2            5 out of 10                    0.020408              0.0
# 3          Not Available                    0.020408              0.0
# 4            3 out of 10                    0.020408              0.0
# ...                  ...                         ...              ...
# 2803         0 out of 10                    0.020408              0.0
# 2804         2 out of 10                    0.020408              0.0
# 2805         0 out of 10                    0.020408              0.0
# 2806         0 out of 10                    0.020408              0.0
# 2807         3 out of 10                    0.020408              0.0
#
#       PC-01 Baseline Rate PC-01 Performance Rate PC-01 Achievement Points  \
# 0                0.000000               0.000000             10 out of 10
# 1                0.295858               0.021739              0 out of 10
# 2                0.027027               0.000000             10 out of 10
# 3           Not Available          Not Available            Not Available
# 4                0.058824               0.000000             10 out of 10
# ...                   ...                    ...                      ...
# 2803        Not Available          Not Available            Not Available
# 2804        Not Available               0.000000             10 out of 10
# 2805        Not Available               0.000000             10 out of 10
# 2806        Not Available               0.045455              0 out of 10
# 2807        Not Available               0.000000             10 out of 10
#
#      PC-01 Improvement Points PC-01 Measure Score
# 0                  0 out of 9        10 out of 10
# 1                  9 out of 9         9 out of 10
# 2                  9 out of 9        10 out of 10
# 3               Not Available       Not Available
# 4                  9 out of 9        10 out of 10
# ...                       ...                 ...
# 2803            Not Available       Not Available
# 2804            Not Available        10 out of 10
# 2805            Not Available        10 out of 10
# 2806            Not Available         0 out of 10
# 2807            Not Available        10 out of 10
#
# [2808 rows x 64 columns]), ('hvbp_efficiency_11_07_2017.csv',       Provider_Number                              Hospital_Name  \
# 0              110215                  PIEDMONT FAYETTE HOSPITAL
# 1              230236                      METRO HEALTH HOSPITAL
# 2              520019              MINISTRY SAINT MARYS HOSPITAL
# 3              340141        NEW HANOVER REGIONAL MEDICAL CENTER
# 4              200020                              YORK HOSPITAL
# ...               ...                                        ...
# 2803            40119                 WHITE RIVER MEDICAL CENTER
# 2804           230075              BRONSON BATTLE CREEK HOSPITAL
# 2805           450867                   SETON NORTHWEST HOSPITAL
# 2806            10078  NORTHEAST ALABAMA REGIONAL MEDICAL CENTER
# 2807           160030                MARY GREELEY MEDICAL CENTER
#
#                            Address          City State  ZIP_Code  \
# 0             1255 HIGHWAY 54 WEST  FAYETTEVILLE    GA     30214
# 1     5900 BYRON CENTER AVENUE, SW       WYOMING    MI     49519
# 2              2251 NORTH SHORE DR   RHINELANDER    WI     54501
# 3          2131 S 17TH ST BOX 9000    WILMINGTON    NC     28402
# 4                15 HOSPITAL DRIVE          YORK    ME      3909
# ...                            ...           ...   ...       ...
# 2803          1710 HARRISON STREET    BATESVILLE    AR     72503
# 2804              300 NORTH AVENUE  BATTLE CREEK    MI     49017
# 2805      11113 RESEARCH BOULEVARD        AUSTIN    TX     78759
# 2806          400 EAST 10TH STREET      ANNISTON    AL     36207
# 2807              1111 DUFF AVENUE          AMES    IA     50010
#
#        County_Name  MSPB-1 Achievement Threshold  MSPB-1 Benchmark  \
# 0          Fayette                      0.985777          0.832678
# 1             Kent                      0.985777          0.832678
# 2           Oneida                      0.985777          0.832678
# 3      New Hanover                      0.985777          0.832678
# 4             York                      0.985777          0.832678
# ...            ...                           ...               ...
# 2803  Independence                      0.985777          0.832678
# 2804       Calhoun                      0.985777          0.832678
# 2805        Travis                      0.985777          0.832678
# 2806       Calhoun                      0.985777          0.832678
# 2807         Story                      0.985777          0.832678
#
#      MSPB-1 Baseline Rate  MSPB-1 Performance Rate MSPB-1 Achievement Points  \
# 0                0.950527                 0.962057               2 out of 10
# 1                0.921788                 0.939953               3 out of 10
# 2                0.843599                 0.832790               9 out of 10
# 3                0.966919                 0.967548               2 out of 10
# 4                0.966664                 0.970079               1 out of 10
# ...                   ...                      ...                       ...
# 2803             0.991526                 0.959543               2 out of 10
# 2804             0.994954                 0.990695               0 out of 10
# 2805             1.020385                 1.009351               0 out of 10
# 2806             0.981114                 1.024099               0 out of 10
# 2807             0.947971                 0.951278               3 out of 10
#
#      MSPB-1 Improvement Points MSPB-1 Measure Score
# 0                   0 out of 9          2 out of 10
# 1                   0 out of 9          3 out of 10
# 2                   9 out of 9          9 out of 10
# 3                   0 out of 9          2 out of 10
# 4                   0 out of 9          1 out of 10
# ...                        ...                  ...
# 2803                2 out of 9          2 out of 10
# 2804                0 out of 9          0 out of 10
# 2805                0 out of 9          0 out of 10
# 2806                0 out of 9          0 out of 10
# 2807                0 out of 9          3 out of 10
#
# [2808 rows x 14 columns]), ('hvbp_hcahps_11_07_2017.csv',       Provider Number                                     Hospital Name  \
# 0              240040  UNIVERSITY MEDICAL CENTER-MESABI/ MESABA CLINICS
# 1              450055                  ROLLING PLAINS MEMORIAL HOSPITAL
# 2               50367                           NORTHBAY MEDICAL CENTER
# 3              360096                      EAST LIVERPOOL CITY HOSPITAL
# 4              230130                      BEAUMONT HOSPITAL, ROYAL OAK
# ...               ...                                               ...
# 2803            40088                     MEDICAL CENTER SOUTH ARKANSAS
# 2804           280023                             CHI HEALTH ST FRANCIS
# 2805           360175                         CLINTON MEMORIAL HOSPITAL
# 2806           340039                     IREDELL MEMORIAL HOSPITAL INC
# 2807           230035                   SPECTRUM HEALTH UNITED HOSPITAL
#
#                              Address            City State  ZIP Code  \
# 0                   750 EAST 34TH ST         HIBBING    MN     55746
# 1                      200 E ARIZONA      SWEETWATER    TX     79556
# 2           1200 B  GALE WILSON BLVD       FAIRFIELD    CA     94533
# 3                425 WEST 5TH STREET  EAST LIVERPOOL    OH     43920
# 4            3601 W THIRTEEN MILE RD       ROYAL OAK    MI     48073
# ...                              ...             ...   ...       ...
# 2803           700 WEST GROVE STREET       EL DORADO    AR     71731
# 2804           2620 WEST FAIDLEY AVE    GRAND ISLAND    NE     68803
# 2805            610 WEST MAIN STREET      WILMINGTON    OH     45177
# 2806  557 BROOKDALE DR  P O BOX 1828     STATESVILLE    NC     28677
# 2807              615 S BOWER STREET      GREENVILLE    MI     48838
#
#       County Name  Communication with Nurses Floor  \
# 0     Saint Louis                            55.27
# 1           Nolan                            55.27
# 2          Solano                            55.27
# 3      Columbiana                            55.27
# 4         Oakland                            55.27
# ...           ...                              ...
# 2803        Union                            55.27
# 2804         Hall                            55.27
# 2805      Clinton                            55.27
# 2806      Iredell                            55.27
# 2807     Montcalm                            55.27
#
#       Communication with Nurses Achievement Threshold  \
# 0                                               78.52
# 1                                               78.52
# 2                                               78.52
# 3                                               78.52
# 4                                               78.52
# ...                                               ...
# 2803                                            78.52
# 2804                                            78.52
# 2805                                            78.52
# 2806                                            78.52
# 2807                                            78.52
#
#       Communication with Nurses Benchmark  ...  \
# 0                                   86.68  ...
# 1                                   86.68  ...
# 2                                   86.68  ...
# 3                                   86.68  ...
# 4                                   86.68  ...
# ...                                   ...  ...
# 2803                                86.68  ...
# 2804                                86.68  ...
# 2805                                86.68  ...
# 2806                                86.68  ...
# 2807                                86.68  ...
#
#      Overall Rating of Hospital Floor  \
# 0                               37.67
# 1                               37.67
# 2                               37.67
# 3                               37.67
# 4                               37.67
# ...                               ...
# 2803                            37.67
# 2804                            37.67
# 2805                            37.67
# 2806                            37.67
# 2807                            37.67
#
#       Overall Rating of Hospital Achievement Threshold  \
# 0                                                70.23
# 1                                                70.23
# 2                                                70.23
# 3                                                70.23
# 4                                                70.23
# ...                                                ...
# 2803                                             70.23
# 2804                                             70.23
# 2805                                             70.23
# 2806                                             70.23
# 2807                                             70.23
#
#      Overall Rating of Hospital Benchmark  \
# 0                                   84.58
# 1                                   84.58
# 2                                   84.58
# 3                                   84.58
# 4                                   84.58
# ...                                   ...
# 2803                                84.58
# 2804                                84.58
# 2805                                84.58
# 2806                                84.58
# 2807                                84.58
#
#      Overall Rating of Hospital Baseline Rate  \
# 0                                       69.20
# 1                                       73.47
# 2                                       69.92
# 3                                       60.70
# 4                                       72.39
# ...                                       ...
# 2803                                    65.53
# 2804                                    70.59
# 2805                                    61.20
# 2806                                    66.36
# 2807                                    76.29
#
#      Overall Rating of Hospital Performance Rate  \
# 0                                          72.81
# 1                                          79.06
# 2                                          71.60
# 3                                          70.32
# 4                                          73.51
# ...                                          ...
# 2803                                       71.70
# 2804                                       68.81
# 2805                                       58.63
# 2806                                       69.64
# 2807                                       79.29
#
#       Overall Rating of Hospital Achievement Points  \
# 0                                       2 out of 10
# 1                                       6 out of 10
# 2                                       1 out of 10
# 3                                       1 out of 10
# 4                                       3 out of 10
# ...                                             ...
# 2803                                    1 out of 10
# 2804                                    0 out of 10
# 2805                                    0 out of 10
# 2806                                    0 out of 10
# 2807                                    6 out of 10
#
#       Overall Rating of Hospital Improvement Points  \
# 0                                        2 out of 9
# 1                                        5 out of 9
# 2                                        1 out of 9
# 3                                        4 out of 9
# 4                                        0 out of 9
# ...                                             ...
# 2803                                     3 out of 9
# 2804                                     0 out of 9
# 2805                                     0 out of 9
# 2806                                     1 out of 9
# 2807                                     3 out of 9
#
#       Overall Rating of Hospital Dimension Score HCAHPS Base Score  \
# 0                                    2 out of 10                29
# 1                                    6 out of 10                49
# 2                                    1 out of 10                10
# 3                                    4 out of 10                29
# 4                                    3 out of 10                 7
# ...                                          ...               ...
# 2803                                 3 out of 10                18
# 2804                                 0 out of 10                 6
# 2805                                 0 out of 10                 2
# 2806                                 1 out of 10                10
# 2807                                 6 out of 10                48
#
#       HCAHPS Consistency Score
# 0                           19
# 1                           20
# 2                           13
# 3                           16
# 4                           14
# ...                        ...
# 2803                        19
# 2804                        15
# 2805                        12
# 2806                        13
# 2807                        20
#
# [2808 rows x 73 columns])])

# %%
for k, v in dfs.items(): #k is the file name, v is the value of the data
    print(
        f'{k} - Number of rows: {v.shape[0]}, Number of columns: {v.shape[1]}'
    )
# Out:
# hvbp_tps_11_07_2017.csv - Number of rows: 2808, Number of columns: 16
# hvbp_clinical_care_11_07_2017.csv - Number of rows: 2808, Number of columns: 28
# hvbp_safety_11_07_2017.csv - Number of rows: 2808, Number of columns: 64
# hvbp_efficiency_11_07_2017.csv - Number of rows: 2808, Number of columns: 14
# hvbp_hcahps_11_07_2017.csv - Number of rows: 2808, Number of columns: 73

# %%
for v in dfs.values():
    for column in v.columns:
        print(column)
    print() #this one is to create space between the end of one file and the beginning of another file.
    #Can try "print ('end of first file')"
    #Check how the key value is written in each file -> Change to make them written in 1 style. (E.g: Provider_Number, Provider-Number,...)
# Out:
# Provider Number
# Hospital Name
# Address
# City
# State
# Zip Code
# County Name
# Unweighted Normalized Clinical Care Domain Score
# Weighted Normalized Clinical Care Domain Score
# Unweighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score
# Weighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score
# Unweighted Normalized Safety Domain Score
# Weighted Safety Domain Score
# Unweighted Normalized Efficiency and Cost Reduction Domain Score
# Weighted Efficiency and Cost Reduction Domain Score
# Total Performance Score
#
# Provider Number
# Hospital Name
# Address
# City
# State
# ZIP Code
# County Name
# MORT-30-AMI Achievement Threshold
# MORT-30-AMI Benchmark
# MORT-30-AMI Baseline Rate
# MORT-30-AMI Performance Rate
# MORT-30-AMI Achievement Points
# MORT-30-AMI Improvement Points
# MORT-30-AMI Measure Score
# MORT-30-HF Achievement Threshold
# MORT-30-HF Benchmark
# MORT-30-HF Baseline Rate
# MORT-30-HF Performance Rate
# MORT-30-HF Achievement Points
# MORT-30-HF Improvement Points
# MORT-30-HF Measure Score
# MORT-30-PN Achievement Threshold
# MORT-30-PN Benchmark
# MORT-30-PN Baseline Rate
# MORT-30-PN Performance Rate
# MORT-30-PN Achievement Points
# MORT-30-PN Improvement Points
# MORT-30-PN Measure Score
#
# Provider Number
# Hospital Name
# Address
# City
# State
# ZIP Code
# County Name
# PSI-90 Achievement Threshold
# PSI-90 Benchmark
# PSI-90 Baseline Rate
# PSI-90 Performance Rate
# PSI-90 Achievement Points
# PSI-90 Improvement Points
# PSI-90 Measure Score
# HAI-1 Achievement Threshold
# HAI-1 Benchmark
# HAI-1 Baseline Rate
# HAI-1 Performance Rate
# HAI-1 Achievement Points
# HAI-1 Improvement Points
# HAI-1 Measure Score
# HAI-2 Achievement Threshold
# HAI-2 Benchmark
# HAI-2 Baseline Rate
# HAI-2 Performance Rate
# HAI-2 Achievement Points
# HAI-2 Improvement Points
# HAI-2 Measure Score
# Combined SSI Measure Score
# HAI-3 Achievement Threshold
# HAI-3 Benchmark
# HAI-3 Baseline Rate
# HAI-3 Performance Rate
# HAI-3 Achievement Points
# HAI-3 Improvement Points
# HAI-3 Measure Score
# HAI-4 Achievement Threshold
# HAI-4 Benchmark
# HAI-4 Baseline Rate
# HAI-4 Performance Rate
# HAI-4 Achievement Points
# HAI-4 Improvement Points
# HAI-4 Measure Score
# HAI-5 Achievement Threshold
# HAI-5 Benchmark
# HAI-5 Baseline Rate
# HAI-5 Performance Rate
# HAI-5 Achievement Points
# HAI-5 Improvement Points
# HAI-5 Measure Score
# HAI-6 Achievement Threshold
# HAI-6 Benchmark
# HAI-6 Baseline Rate
# HAI-6 Performance Rate
# HAI-6 Achievement Points
# HAI-6 Improvement Points
# HAI-6 Measure Score
# PC-01 Achievement Threshold
# PC-01 Benchmark
# PC-01 Baseline Rate
# PC-01 Performance Rate
# PC-01 Achievement Points
# PC-01 Improvement Points
# PC-01 Measure Score
#
# Provider_Number
# Hospital_Name
# Address
# City
# State
# ZIP_Code
# County_Name
# MSPB-1 Achievement Threshold
# MSPB-1 Benchmark
# MSPB-1 Baseline Rate
# MSPB-1 Performance Rate
# MSPB-1 Achievement Points
# MSPB-1 Improvement Points
# MSPB-1 Measure Score
#
# Provider Number
# Hospital Name
# Address
# City
# State
# ZIP Code
# County Name
# Communication with Nurses Floor
# Communication with Nurses Achievement Threshold
# Communication with Nurses Benchmark
# Communication with Nurses Baseline Rate
# Communication with Nurses Performance Rate
# Communication with Nurses Achievement Points
# Communication with Nurses Improvement Points
# Communication with Nurses Dimension Score
# Communication with Doctors Floor
# Communication with Doctors Achievement Threshold
# Communication with Doctors Benchmark
# Communication with Doctors Baseline Rate
# Communication with Doctors Performance Rate
# Communication with Doctors Achievement Points
# Communication with Doctors Improvement Points
# Communication with Doctors Dimension Score
# Responsiveness of Hospital Staff Floor
# Responsiveness of Hospital Staff Achievement Threshold
# Responsiveness of Hospital Staff Benchmark
# Responsiveness of Hospital Staff Baseline Rate
# Responsiveness of Hospital Staff Performance Rate
# Responsiveness of Hospital Staff Achievement Points
# Responsiveness of Hospital Staff Improvement Points
# Responsiveness of Hospital Staff Dimension Score
# Care Transition Floor
# Care Transition Achievement Threshold
# Care Transition Benchmark
# Care Transition Baseline Rate
# Care Transition Performance Rate
# Care Transition Achievement Points
# Care Transition Improvement Points
# Care Transition Dimension Score
# Communication about Medicines Floor
# Communication about Medicines Achievement Threshold
# Communication about Medicines Benchmark
# Communication about Medicines Baseline Rate
# Communication about Medicines Performance Rate
# Communication about Medicines Achievement Points
# Communication about Medicines Improvement Points
# Communication about Medicines Dimension Score
# Cleanliness and Quietness of Hospital Environment Floor
# Cleanliness and Quietness of Hospital Environment Achievement Threshold
# Cleanliness and Quietness of Hospital Environment Benchmark
# Cleanliness and Quietness of Hospital Environment Baseline Rate
# Cleanliness and Quietness of Hospital Environment Performance Rate
# Cleanliness and Quietness of Hospital Environment Achievement Points
# Cleanliness and Quietness of Hospital Environment Improvement Points
# Cleanliness and Quietness of Hospital Environment Dimension Score
# Discharge Information Floor
# Discharge Information Achievement Threshold
# Discharge Information Benchmark
# Discharge Information Baseline Rate
# Discharge Information Performance Rate
# Discharge Information Achievement Points
# Discharge Information Improvement Points
# Discharge Information Dimension Score
# Overall Rating of Hospital Floor
# Overall Rating of Hospital Achievement Threshold
# Overall Rating of Hospital Benchmark
# Overall Rating of Hospital Baseline Rate
# Overall Rating of Hospital Performance Rate
# Overall Rating of Hospital Achievement Points
# Overall Rating of Hospital Improvement Points
# Overall Rating of Hospital Dimension Score
# HCAHPS Base Score
# HCAHPS Consistency Score

# %%
#Unify the key across all datasets to be Provider Number (as one of them is Provider_Number)
for df in dfs.values():
    df.rename(columns={'Provider_Number': 'Provider Number'}, inplace=True)

#Optional you can run the command above to make sure that they all become Provider Number

# %%
dfs[files_of_interest[0]].head()
#this is equivalent of df1 (the first dataframe in the dictionary)
# Out:
#    Provider Number                     Hospital Name  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1            10005     MARSHALL MEDICAL CENTER SOUTH
# 2            10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3            10007          MIZELL MEMORIAL HOSPITAL
# 4            10011                 ST VINCENT'S EAST
#
#                       Address        City State  Zip Code County Name  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301     Houston
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957    Marshall
# 2          205 MARENGO STREET    FLORENCE    AL     35631  Lauderdale
# 3               702 N MAIN ST         OPP    AL     36467   Covington
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235   Jefferson
#
#   Unweighted Normalized Clinical Care Domain Score  \
# 0                                  43.333333333333
# 1                                  16.666666666667
# 2                                  26.666666666667
# 3                                  26.666666666667
# 4                                  46.666666666667
#
#   Weighted Normalized Clinical Care Domain Score  \
# 0                                10.833333333333
# 1                                 4.166666666667
# 2                                 6.666666666667
# 3                                 8.888888888889
# 4                                11.666666666667
#
#   Unweighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                    26.000000000000
# 1                                    36.000000000000
# 2                                    17.000000000000
# 3                                    56.000000000000
# 4                                    25.000000000000
#
#   Weighted Patient and Caregiver Centered Experience of Care/Care Coordination Domain Score  \
# 0                                     6.500000000000
# 1                                     9.000000000000
# 2                                     4.250000000000
# 3                                    18.666666666667
# 4                                     6.250000000000
#
#   Unweighted Normalized Safety Domain Score Weighted Safety Domain Score  \
# 0                           72.857142857143              18.214285714286
# 1                           81.428571428571              20.357142857143
# 2                           47.142857142857              11.785714285714
# 3                             Not Available                Not Available
# 4                           42.857142857143              10.714285714286
#
#   Unweighted Normalized Efficiency and Cost Reduction Domain Score  \
# 0                                     0.000000000000
# 1                                     0.000000000000
# 2                                     0.000000000000
# 3                                     0.000000000000
# 4                                     0.000000000000
#
#   Weighted Efficiency and Cost Reduction Domain Score Total Performance Score
# 0                                     0.000000000000          35.547619047619
# 1                                     0.000000000000          33.523809523810
# 2                                     0.000000000000          22.702380952381
# 3                                     0.000000000000          27.555555555556
# 4                                     0.000000000000          28.630952380952

# %%
#Joining the 5 files together on Provider Number
#Start with first file
df_master = dfs[files_of_interest[0]]

for foi in files_of_interest[1:]:  #Meaning from 1 and all the way to the end.
    df_master = df_master.merge(
        dfs[foi],
        on='Provider Number',
        how='left',
        copy=False
    )

print(df_master.shape)

#Error: Passing 'suffixes' which cause duplicate columns {'Address_x', 'State_x', 'City_x'} is not allowed. -> We need to clean the duplicated columns.
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /tmp/ipython-input-1559257329.py in <cell line: 0>()
#       4
#       5 for foi in files_of_interest[1:]:
# ----> 6     df_master = df_master.merge(
#       7         dfs[foi],
#       8         on='Provider Number',
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     182             validate=validate,
#     183         )
# --> 184         return op.get_result(copy=copy)
#     185
#     186
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     886         join_index, left_indexer, right_indexer = self._get_join_info()
#     887
# --> 888         result = self._reindex_and_concat(
#     889             join_index, left_indexer, right_indexer, copy=copy
#     890         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     838         right = self.right[:]
#     839
# --> 840         llabels, rlabels = _items_overlap_with_suffix(
#     841             self.left._info_axis, self.right._info_axis, self.suffixes
#     842         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2755         dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756     if dups:
# -> 2757         raise MergeError(
#    2758             f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759             f"not allowed.",
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'Address_x', 'State_x', 'City_x'} is not allowed.

# %%
from collections import Counter. #Counter is the function from the 'collections' library.

# Step 1: Collect all column names from all dataframes
all_columns = []
for df in dfs.values():
    all_columns.extend(df.columns). #extend: give me all columns names even when they are duplicated.

# Step 2: Count how many times each column appears
column_counts = Counter(all_columns)

# Step 3: Find columns that appear more than once (excluding merge key)
common_cols = {col for col, count in column_counts.items()
               if count > 1 and col != 'Provider Number'} #'!=' means not equal.

print(f"Columns to drop: {common_cols}")
# Out:
# Columns to drop: {'City', 'County Name', 'Hospital Name', 'Address', 'ZIP Code', 'State'}

# %%
for col, count in column_counts.most_common():
    if count > 1:
        print(f"{col}: {count} times")
# Out:
# Provider Number: 5 times
# Address: 5 times
# City: 5 times
# State: 5 times
# Hospital Name: 4 times
# County Name: 4 times
# ZIP Code: 3 times

# %%
# Start with the first dataframe
df_master = dfs[files_of_interest[0]]

# Merge the rest, dropping duplicate columns
for foi in files_of_interest[1:]:
    df_to_merge = dfs[foi].drop(columns=common_cols, errors='ignore')
    df_master = df_master.merge(
        df_to_merge,
        on='Provider Number',
        how='left',
        copy=False
    )

print(df_master.shape)
# Out:
# (2808, 170)

# %%
#Writing csv file from the dataset in Python.
df_master.to_csv('hvbp.csv', index=False) #'hvbp.cvs' is the file name.
#Then check folders on the left

# %%
#New Python concept
#List comprehension example

#Remember this from loops?

def f_to_c(temp_f):
    return (temp_f - 32) * 5/9

temps_f = [32, 68, 98.6, 212]
temps_c = []
for temp in temps_f:
    temps_c.append(f_to_c(temp))

print(temps_c)  # [0.0, 20.0, 37.0, 100.0]
# Out:
# [0.0, 20.0, 37.0, 100.0]

# %%
def f_to_c(temp_f):
    return (temp_f - 32) * 5/9

temps_f = [32, 68, 98.6, 212]
temps_c = [f_to_c(temp) for temp in temps_f] #list comprehension

print(temps_c)  # [0.0, 20.0, 37.0, 100.0]
# Out:
# [0.0, 20.0, 37.0, 100.0]
